# %% [markdown]
# # Decision support system model
#
# ## Problem Statement
# Predict potential clients who are most likely to open a bank account
#
# ## Data Description
#
#
# The file has the below structure:
# ### insert structure

# %% [markdown]
# ## EDA
# The general steps we'll follow are:
# - Import the required libraries for EDA
# - Loading the data into the data frame
# - Descriptive statistics
#     - Checking the types of data
#     - Get and understand some statistics from the dataset e.g. central tendancy, count, mean, standard deviation, minimum values, maximum values, quartiles and the median e.t.c
# - Infrerential statitics
# - Visualization
#     - Plot different features against one another ()
#     - Plot different features against their frequency ()
#     - Plotting Heat-maps
# - Hyposthes testing
#     - Deriving Insights and Conclusions that would guide the approach you take for training our machine learning model
# - Modelling

# %%
# !ls
# Out:
# legroupe.ipynb	    Test_v2.csv   VariableDefinitions.csv
# SubmissionFile.csv  Train_v2.csv

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import pandas as pd


#Import PP
import pandas_profiling as pp

# %% [markdown]
# ## Load data

# %%
data_f = pd.read_csv('Train_v2.csv')
test_df = pd.read_csv('Test_v2.csv')
data_f.sample(10)
# Out:
#         country  year       uniqueid bank_account location_type  \
# 10545    Rwanda  2016  uniqueid_4478           No         Rural
# 7120     Rwanda  2016  uniqueid_1053           No         Urban
# 11767    Rwanda  2016  uniqueid_5700           No         Rural
# 23161    Uganda  2018  uniqueid_1739           No         Rural
# 18621  Tanzania  2017  uniqueid_3819           No         Urban
# 19941  Tanzania  2017  uniqueid_5139           No         Urban
# 9017     Rwanda  2016  uniqueid_2950           No         Rural
# 12877    Rwanda  2016  uniqueid_6810           No         Rural
# 21991    Uganda  2018   uniqueid_569           No         Rural
# 8604     Rwanda  2016  uniqueid_2537           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 10545              Yes               5                 69
# 7120               Yes               8                 18
# 11767              Yes               5                 37
# 23161              Yes               5                 38
# 18621               No               4                 17
# 19941              Yes               2                 34
# 9017               Yes               3                 35
# 12877               No               2                 21
# 21991              Yes               8                 50
# 8604               Yes               8                 51
#
#       gender_of_respondent relationship_with_head           marital_status  \
# 10545               Female                 Spouse  Married/Living together
# 7120                Female    Other non-relatives     Single/Never Married
# 11767               Female      Head of Household                  Widowed
# 23161               Female                 Spouse  Married/Living together
# 18621                 Male    Other non-relatives       Divorced/Seperated
# 19941                 Male      Head of Household     Single/Never Married
# 9017                Female      Head of Household       Divorced/Seperated
# 12877               Female                 Spouse  Married/Living together
# 21991                 Male      Head of Household  Married/Living together
# 8604                  Male      Head of Household  Married/Living together
#
#                        education_level             job_type
# 10545              No formal education  Farming and Fishing
# 7120                 Primary education  Informally employed
# 11767                Primary education  Farming and Fishing
# 23161  Vocational/Specialised training        Self employed
# 18621                Primary education            No Income
# 19941                Primary education        Self employed
# 9017                 Primary education  Farming and Fishing
# 12877                Primary education  Informally employed
# 21991              Secondary education        Self employed
# 8604                 Primary education  Farming and Fishing

# %%
pp.ProfileReport(data_f)
# Out:
# /home/dan/anaconda3/lib/python3.7/site-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>23524 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.3 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>104.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_uniqueid"><code>uniqueid</code></a> has a high cardinality: 8735 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_country">country<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>4</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable5226023611417878143">
#     <table class="mini freq">
#         <tr class="">
#     <th>Rwanda</th>
#     <td>
#         <div class="bar" style="width:100%" data-toggle="tooltip" data-placement="right" data-html="true"
#              data-delay=500 title="Percentage: 37.1%">

# %% [markdown]
# ### Seems we're in luck. Our data is very clean
# ### We have 3 numeric and 9 cataegorical variables(excluding bank_account).
# ### Please have a look at the PP report above for more info
